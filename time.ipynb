# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from    statsmodels.tsa.seasonal import   seasonal_decompose

# %%
Turnover=pd.read_csv("Champagne.csv",parse_dates=True)
Turnover.head()
# Out:
#      Month  Monthly Champagne Sales
# 0  1964-01                     2815
# 1  1964-02                     2672
# 2  1964-03                     2755
# 3  1964-04                     2721
# 4  1964-05                     2946

# %%
import statsmodels.api as sn

# %%
decomTurnover=sn.tsa.seasonal_decompose(Turnover["Monthly Champagne Sales"],model="multiplicative",freq=12)
decomTurnover.plot()
plt.show()

# %%
decompTurnover = sn.tsa.seasonal_decompose(Turnover["Monthly Champagne Sales"], model="additive", freq=12)
decompTurnover.plot()
plt.show()

# %%
a=pd.read_csv("AirPassenger.csv",parse_dates=["Year-Month"],index_col="Year-Month")
a.head()
# Out:
#             International Airlines Pax
# Year-Month
# 1949-01-01                         112
# 1949-02-01                         118
# 1949-03-01                         132
# 1949-04-01                         129
# 1949-05-01                         121

# %%
mvg_avg_pax                       = a.copy()
mvg_avg_pax['moving_avg_forecast'] =a["International Airlines Pax"].rolling(3).mean()

plt.plot(a["International Airlines Pax"], label='international airlines')
plt.plot(mvg_avg_pax['moving_avg_forecast'], label='avg international airlines pax')
plt.legend(loc='best')
plt.show()

# %%
index_a=a.set_index["Year-Month"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-e1a1a92e8b79> in <module>
# ----> 1 index_a=a.set_index["Year-Month"]
#
# TypeError: 'method' object is not subscriptable

# %%
rolling1      =  a.rolling(window = 3) # arbitrarily chosen

rolling_mean1 =  rolling1.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f8f87f931389> in <module>
# ----> 1 rolling1      =  indexeda.rolling(window = 3) # arbitrarily chosen
#       2
#       3 rolling_mean1 =  rolling1.mean()
#
# NameError: name 'indexeda' is not defined

# %%
y_df = pd.DataFrame( {'Observed':a.values, 'Predicted':rolling_mean1})
y_df .dropna(axis = 0, inplace = True)
print(y_df.tail())

rmse = np.sqrt(mean_squared_error(y_df.Observed, y_df.Predicted))
print("\n\n Accuracy measures ")
print('RMSE: %.3f' % rmse)
n = y_df.shape[0]

mae = MAE(y_df.Observed, y_df.Predicted)
print('MAE: %d' % np.float(mae))

mape = MAPE(y_df.Observed, y_df.Predicted)
print('MAPE: %.3f' % np.float(mape))

# %%
df=pd.read_csv("airline-passengers.csv", header=0, index_col=0, parse_dates=True, squeeze=True)
df.head()
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# Name: Passengers, dtype: int64

# %%
series       =  pd.read_csv('airline-passengers.csv', 
                         header=0, index_col=0, parse_dates=True, squeeze=True)

# %%
from datetime import datetime

# %%
from sklearn.metrics import mean_squared_error

# %%
df["Month"]=pd.to_datetime(df["Month"],infer_datetime_format=True)

# %%
df.head()
# Out:
#        Month  Passengers
# 0 1949-01-01         112
# 1 1949-02-01         118
# 2 1949-03-01         132
# 3 1949-04-01         129
# 4 1949-05-01         121

# %%
indexed_dataset=df.set_index("Month")

# %%
indexed_dataset.head()
# Out:
#          Passengers
# Month
# 1949-01         112
# 1949-02         118
# 1949-03         132
# 1949-04         129
# 1949-05         121

# %%
rolling1   =  df.rolling(window = 12).mean() # arbitrarily chosen

#rolling_mean1 =  rolling1.mean()

# %%
rolling1
# Out:
#          Passengers
# Month
# 1949-01         NaN
# 1949-02         NaN
# 1949-03         NaN
# 1949-04         NaN
# 1949-05         NaN
# 1949-06         NaN
# 1949-07         NaN
# 1949-08         NaN
# 1949-09         NaN
# 1949-10         NaN
# 1949-11         NaN
# 1949-12  126.666667
# 1950-01  126.916667
# 1950-02  127.583333
# 1950-03  128.333333
# 1950-04  128.833333
# 1950-05  129.166667
# 1950-06  130.333333
# 1950-07  132.166667
# 1950-08  134.000000
# 1950-09  135.833333
# 1950-10  137.000000
# 1950-11  137.833333
# 1950-12  139.666667
# 1951-01  142.166667
# 1951-02  144.166667
# 1951-03  147.250000
# 1951-04  149.583333
# 1951-05  153.500000
# 1951-06  155.916667
# ...             ...
# 1958-07  376.333333
# 1958-08  379.500000
# 1958-09  379.500000
# 1958-10  380.500000
# 1958-11  380.916667
# 1958-12  381.000000
# 1959-01  382.666667
# 1959-02  384.666667
# 1959-03  388.333333
# 1959-04  392.333333
# 1959-05  397.083333
# 1959-06  400.166667
# 1959-07  404.916667
# ...

# %%
rolling1.dropna(inplace=True)

# %%
y_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-cfb696739f05> in <module>
# ----> 1 y_df.head()
#
# NameError: name 'y_df' is not defined

# %%
y_df = pd.DataFrame( {'Observed':df.values, 'Predicted':rolling1})

# %%
import numpy as np

# %%
y_df = pd.DataFrame( {'Observed':df.values, 'Predicted':rolling1})
y_df .dropna(axis = 0, inplace = True)
print(y_df.tail())

rmse = np.sqrt(mean_squared_error(y_df.Observed, y_df.Predicted))
print("\n\n Accuracy measures ")
print('RMSE: %.3f' % rmse)
n = y_df.shape[0]

mae = MAE(y_df.Observed, y_df.Predicted)
print('MAE: %d' % np.float(mae))

mape = MAPE(y_df.Observed, y_df.Predicted)
print('MAPE: %.3f' % np.float(mape))
# Out:
#             Observed   Predicted
# Month
# 1960-08-01       606  463.333333
# 1960-09-01       508  467.083333
# 1960-10-01       461  471.583333
# 1960-11-01       390  473.916667
# 1960-12-01       432  476.166667
#
#
#  Accuracy measures
# RMSE: 48.009
# MAE: 34
# MAPE: 10.780

# %%
def MAE(y,yhat):
    diff = np.abs(np.array(y)-np.array(yhat))
    try:
        mae =  round(np.mean(np.fabs(diff)),3)
    except:
        print("Error while calculating")
        mae = np.nan
    return mae

# %%
def MAPE(y, yhat): 
    y, yhat = np.array(y), np.array(yhat)
    try:
        mape =  round(np.mean(np.abs((y - yhat) / y)) * 100,2)
    except:
        print("Observed values are empty")
        mape = np.nan
    return mape

# %%
import pandas as pd

# %%
Tractor=pd.read_csv("TractorSales.csv",parse_dates=True,index_col=0)
Tractor.head()
# Out:
#             Number of Tractor Sold
# Month-Year
# 3-Jan                          141
# 3-Feb                          157
# 3-Mar                          185
# 3-Apr                          199
# 3-May                          203

# %%
dates = pd.date_range(start='2003-01-01', freq='MS', periods=len(Tractor))

# %%
import calendar
Tractor['Month'] = dates.month
Tractor['Month'] = Tractor['Month'].apply(lambda x: calendar.month_abbr[x])
Tractor['Year'] = dates.year

# %%
#Tractor.drop(['Month-Year'], axis=1, inplace=True)
Tractor.rename(columns={'Number of Tractor Sold':'Tractor-Sales'}, inplace=True)
Tractor = Tractor[['Month', 'Year', 'Tractor-Sales']]

# %%
Tractor.set_index(dates, inplace=True)

# %%
Tractor = Tractor[['Tractor-Sales']]
Tractor
# Out:
#             Tractor-Sales
# 2003-01-01            141
# 2003-02-01            157
# 2003-03-01            185
# 2003-04-01            199
# 2003-05-01            203
# 2003-06-01            189
# 2003-07-01            207
# 2003-08-01            207
# 2003-09-01            171
# 2003-10-01            150
# 2003-11-01            138
# 2003-12-01            165
# 2004-01-01            145
# 2004-02-01            168
# 2004-03-01            197
# 2004-04-01            208
# 2004-05-01            210
# 2004-06-01            209
# 2004-07-01            238
# 2004-08-01            238
# 2004-09-01            199
# 2004-10-01            168
# 2004-11-01            152
# 2004-12-01            196
# 2005-01-01            183
# 2005-02-01            200
# 2005-03-01            249
# 2005-04-01            251
# 2005-05-01            289
# 2005-06-01            249
# ...                   ...
# 2012-07-01            687
# 2012-08-01            707
# 2012-09-01            509
# ...

# %%
Tractor.tail()
# Out:
#             Tractor-Sales
# 2014-08-01            848
# 2014-09-01            640
# 2014-10-01            581
# 2014-11-01            519
# 2014-12-01            605

# %%
decompTurnover = sn.tsa.seasonal_decompose(Tractor["Tractor-Sales"], model="additive", freq=12)
decompTurnover.plot()
plt.show()

# %%
decompTurnover = sn.tsa.seasonal_decompose(Tractor["Tractor-Sales"], model="multiplicative", freq=12)
decompTurnover.plot()
plt.show()

# %%
mvg_avg_tractor                       = Tractor.copy()
mvg_avg_tractor['moving_avg_forecast'] = Tractor["Tractor-Sales"].rolling(3).mean()

plt.plot(Tractor["Tractor-Sales"], label='tractor_sales')
plt.plot(mvg_avg_tractor['moving_avg_forecast'], label='avg tractor sale')
plt.legend(loc='best')
plt.show()

# %%
rolling      =  Tractor.rolling(window = 3) # arbitrarily chosen

rolling_mean =  rolling.mean()

# %%
Tractor.head()

# %%
y_df = pd.DataFrame( {'Observed':Tractor.values, 'Predicted':rolling_mean})
y_df .dropna(axis = 0, inplace = True)
print(y_df.tail())

rmse = np.sqrt(mean_squared_error(y_df.Observed, y_df.Predicted))
print("\n\n Accuracy measures ")
print('RMSE: %.3f' % rmse)
n = y_df.shape[0]

mae = MAE(y_df.Observed, y_df.Predicted)
print('MAE: %d' % np.float(mae))

mape = MAPE(y_df.Observed, y_df.Predicted)
print('MAPE: %.3f' % np.float(mape))

# %%
import pandas as pd

# %%
petrol=pd.read_csv("Petrol.csv")
petrol.head()
# Out:
#    Year Quarter  Consumption
# 0  2001      Q1       14.978
# 1  2001      Q2       11.099
# 2  2001      Q3       10.057
# 3  2001      Q4       10.454
# 4  2002      Q1        9.295

# %%
date_rng=pd.date_range(start='1/1/2001',end='30/9/2013',freq='Q')

# %%
petrol["Time index"]=pd.DataFrame(date_rng,columns=['Quarter'])

# %%
petrol.head()
# Out:
#    Year Quarter  Consumption  Timeindex Time index
# 0  2001      Q1       14.978 2001-03-31 2001-03-31
# 1  2001      Q2       11.099 2001-06-30 2001-06-30
# 2  2001      Q3       10.057 2001-09-30 2001-09-30
# 3  2001      Q4       10.454 2001-12-31 2001-12-31
# 4  2002      Q1        9.295 2002-03-31 2002-03-31

# %%
plt.plot(Petrol.Consumption)
